# %%
from model.model import TurbineMonitor
import pandas as pd

# %%
Data = 'data/T1.csv'
df = pd.read_csv(Data, sep=',')

# %%
monitor = TurbineMonitor(model_path='model/wind_turbine_power_model.pkl')

# %%
for index, row in df.sample(30).iterrows():
    monitor.report(
        row['Wind Speed (m/s)'],
        row['Wind Direction (°)'],
        row['LV ActivePower (kW)']
    )
# Out:
# ✅ Normal operation. Expected ~128 kW, actual 247 kW.
# ✅ Normal operation. Expected ~581 kW, actual 567 kW.
# ✅ Normal operation. Expected ~1513 kW, actual 1368 kW.
# ✅ Normal operation. Expected ~0 kW, actual 0 kW.
# ✅ Normal operation. Expected ~506 kW, actual 422 kW.
# ✅ Normal operation. Expected ~1553 kW, actual 1551 kW.
# ⚠️ ALERT: Turbine underperforming. Expected ~1626 kW, actual 0 kW (deficit: 1626 kW). Recommend inspection.
# ✅ Normal operation. Expected ~3572 kW, actual 3603 kW.
# ✅ Normal operation. Expected ~2343 kW, actual 2411 kW.
# ✅ Normal operation. Expected ~3495 kW, actual 3440 kW.
# ✅ Normal operation. Expected ~657 kW, actual 590 kW.
# ✅ Normal operation. Expected ~2619 kW, actual 2706 kW.
# ✅ Normal operation. Expected ~0 kW, actual 0 kW.
# ✅ Normal operation. Expected ~2399 kW, actual 2396 kW.
# ✅ Normal operation. Expected ~190 kW, actual 192 kW.
# ✅ Normal operation. Expected ~2108 kW, actual 2408 kW.
# ✅ Normal operation. Expected ~3291 kW, actual 3226 kW.
# ✅ Normal operation. Expected ~3345 kW, actual 3323 kW.
# ✅ Normal operation. Expected ~3565 kW, actual 3596 kW.
# ✅ Normal operation. Expected ~2573 kW, actual 2568 kW.
# ✅ Normal operation. Expected ~3456 kW, actual 3435 kW.
# ✅ Normal operation. Expected ~1 kW, actual 11 kW.
# ✅ Normal operation. Expected ~86 kW, actual 101 kW.
# ✅ Normal operation. Expected ~571 kW, actual 606 kW.
# ✅ Normal operation. Expected ~0 kW, actual 0 kW.
# ✅ Normal operation. Expected ~623 kW, actual 621 kW.
# ✅ Normal operation. Expected ~3393 kW, actual 3420 kW.
# ✅ Normal operation. Expected ~2758 kW, actual 2769 kW.
# ✅ Normal operation. Expected ~0 kW, actual 0 kW.
# ✅ Normal operation. Expected ~859 kW, actual 982 kW.
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /home/bbo/Documents/Code/projects/WInd turbine anomaly detection/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
